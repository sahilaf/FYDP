# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilaf/FYDP/blob/main/SyncTalk_2d_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Git clone

# %%
# !git clone https://github.com/ZiqiaoPeng/SyncTalk_2D.git
# %cd SyncTalk_2D
# Out:
# Cloning into 'SyncTalk_2D'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 57 (delta 14), reused 7 (delta 7), pack-reused 32 (from 1)
# Receiving objects: 100% (57/57), 17.85 MiB | 17.04 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/SyncTalk_2D

# %% [markdown]
# # Dependencies

# %%
# !pip install torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0 --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install opencv-python transformers soundfile librosa onnxruntime-gpu configargparse
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.2/757.2 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 91.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 74.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 119.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 150.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 22.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Correct Numpy version install
#
# after the install is done might need to restart don't re-run the cell after restart.

# %%
# !pip install "numpy<2.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 125.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2656/3773301250.py in <cell line: 0>()
# ----> 1 get_ipython().system('pip install "numpy<2.0"')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97
#      98     if pip_warn:
# ---> 99       _pip.print_previous_import_warning(output)
#     100
#     101   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
# ...

# %%
# %cd SyncTalk_2D
# Out:
# /content/SyncTalk_2D

# %% [markdown]
# Make directory and move file don't need to move manually video is placed and if running with drive . change the path if needed. Make a directory name SyncTalk_2D/dataset everything will stay there. After training zip and save dataset folder and also zip the checkpoint folder in drive and save.

# %%
# !mkdir -p dataset/red
# !mv /content/red.mp4 dataset/red/red.mp4
# Out:
# mv: cannot stat '/content/red.mp4': No such file or directory

# %% [markdown]
# Model training change the (red) name with dataset name

# %%
# !bash training_328.sh red 0
# Out:
# [INFO] ===== extract audio from ./dataset/red/red.mp4 to ./dataset/red/aud.wav =====
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# # Inference run with input audio keep the file type mp3

# %%
# !python inference_328.py --name red --audio_path /content/input.mp3
# Out:
# ./checkpoint/red/99.pth
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# ave
# 100% 1121/1121 [00:38<00:00, 29.42it/s]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %% [markdown]
# Commands to move run and zip if needed

# %%
# !mv /content/SyncTalk_2D/dataset/redwan /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset

# %%
# !mv /content/SyncTalk_2D/checkpoint/redwan /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint

# %%
# !tar -cvf redwan.tar /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan
from google.colab import files
files.download("redwan.tar")
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5219.jpg
# tar: /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5219.jpg: file changed as we read it
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5220.jpg
# tar: /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5220.jpg: file changed as we read it
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5221.jpg
# tar: /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5221.jpg: file changed as we read it
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5222.jpg
# tar: /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5222.jpg: file changed as we read it
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/dataset/redwan/full_body_img/5223.jpg
# ...

# %%
# !tar -cvf checkpoint_redwan.tar /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint/redwan
from google.colab import files
files.download("checkpoint_redwan.tar")
# Out:
# tar: Removing leading `/' from member names
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint/redwan/
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint/redwan/4.pth
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint/redwan/9.pth
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint/redwan/14.pth
# /content/drive/MyDrive/Fydp_repo/SyncTalk_2D/checkpoint/redwan/19.pth
